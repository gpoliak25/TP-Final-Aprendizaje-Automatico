# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # MAESTRÍA EN CIENCIA DE DATOS E INNOVACIÓN EMPRESARIAL
# # Aprendizaje Automático - Deep Learning
#
#
# **TRABAJO FINAL**
#
# *Alumnos:
# Apellido, Nombre1
# Apellido, Nombre2
# Apellido, Nombre3
# Apellido, Nombre4*
#
# Docente: Joaquín Pedre
#
# Junio 2024

# %% [markdown]
# **Resumen :**
#
#  Presentar los objetivos del trabajo final integrador, el problema que intentarán resolver, las herramientas y metodologías  que utilizarán, justificando adecuadamente.
#
#  En caso de adicionar una Notebook (es recomendable), indicar el dataset utilizado y la fuente.

# %%
# Código comentado 
# El código debe haber sido ejecutado previamente para verificar que no tiene errores
# Los datos deben estar accesibles para poder correr el script.

# El script debe contener:
#1- Importación de todas las librerías necesarias
#2- Lectura de datos 
#3- Definición de la/s arquitectura/s utilizadas
#4- Resolución del problema
#5- Evaluación, indicando la medida de bondad utilizada (usar las métricas apropiadas para el caso)

# %% [markdown]
# **Conclusiones**: describir brevemente las conclusiones obtenidas a partir de la resolución propuesta (no más de 5 reglones)
